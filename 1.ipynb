# %%
a = 21
b = "Harsh"
c = 6.2

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(32))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))
print("Hello", name)
print("Your Age: ",age)
# Out:
# Hello Harsh
# Age 21

# %%
age = int(input("Enter Age: "))
if age > 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")
# Out:
# Eligible to Vote

# %%
num = -12

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Negative

# %%
num = 10

if num > 0:
    if num % 2 == 0:
        print("Positive Even")
# Out:
# Positive Even

# %%
a = [1,2,3]
b = [1,2,3]

print(a == b) # Values Same
print(a is b) # Memory is Different
# Out:
# True
# False
